# %%
# %load_ext autoreload
# %autoreload 2

from train import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
history = train(num_epochs=20, optim='adagrad')
# Out:
# Loading train data
#
# Finished loading data
#
# Loading val data
#
# Finished loading data
#
# Model: "AlphaNet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 64, 64, 16)        1216
# _________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)   (None, 64, 64, 16)        0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 32, 32, 16)        0
# _________________________________________________________________
# spatial_dropout2d_7 (Spatial (None, 32, 32, 16)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 32, 32, 32)        12832
# _________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)   (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# spatial_dropout2d_8 (Spatial (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)   (None, 16, 16, 32)        0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# spatial_dropout2d_9 (Spatial (None, 8, 8, 32)          0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 1024)              4096
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 1024)              0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               524800
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 512)               2048
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 512)               0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 200)               102600
# =================================================================
# Total params: 2,755,016
# Trainable params: 2,751,944
# Non-trainable params: 3,072
# _________________________________________________________________
# Train on 100000 samples, validate on 10000 samples
# Epoch 1/20
#  - 31s - loss: 3.9685 - accuracy: 0.1516 - val_loss: 3.5663 - val_accuracy: 0.2193
# Epoch 2/20
#  - 30s - loss: 3.7097 - accuracy: 0.1858 - val_loss: 3.5620 - val_accuracy: 0.2172
# Epoch 3/20
#  - 30s - loss: 3.6382 - accuracy: 0.1994 - val_loss: 3.4857 - val_accuracy: 0.2302
# Epoch 4/20
#  - 30s - loss: 3.5863 - accuracy: 0.2088 - val_loss: 3.4884 - val_accuracy: 0.2301
# Epoch 5/20
#  - 30s - loss: 3.5576 - accuracy: 0.2098 - val_loss: 3.4776 - val_accuracy: 0.2322
# Epoch 6/20
#  - 30s - loss: 3.5232 - accuracy: 0.2178 - val_loss: 3.4509 - val_accuracy: 0.2347
# Epoch 7/20
#  - 30s - loss: 3.4963 - accuracy: 0.2211 - val_loss: 3.4378 - val_accuracy: 0.2385
# Epoch 8/20
#  - 30s - loss: 3.4802 - accuracy: 0.2251 - val_loss: 3.4352 - val_accuracy: 0.2399
# Epoch 9/20
#  - 30s - loss: 3.4610 - accuracy: 0.2269 - val_loss: 3.4325 - val_accuracy: 0.2394
# Epoch 10/20
#  - 30s - loss: 3.4432 - accuracy: 0.2311 - val_loss: 3.4155 - val_accuracy: 0.2445
# Epoch 11/20
#  - 30s - loss: 3.4226 - accuracy: 0.2347 - val_loss: 3.4098 - val_accuracy: 0.2433
# Epoch 12/20
#  - 30s - loss: 3.4102 - accuracy: 0.2350 - val_loss: 3.4181 - val_accuracy: 0.2448
# Epoch 13/20
#  - 30s - loss: 3.3997 - accuracy: 0.2376 - val_loss: 3.4254 - val_accuracy: 0.2422
# Epoch 14/20
#  - 30s - loss: 3.3837 - accuracy: 0.2385 - val_loss: 3.4086 - val_accuracy: 0.2463
# Epoch 15/20
#  - 30s - loss: 3.3754 - accuracy: 0.2395 - val_loss: 3.4053 - val_accuracy: 0.2489
# Epoch 16/20
#  - 30s - loss: 3.3649 - accuracy: 0.2415 - val_loss: 3.4030 - val_accuracy: 0.2482
# Epoch 17/20
#  - 30s - loss: 3.3499 - accuracy: 0.2435 - val_loss: 3.3910 - val_accuracy: 0.2499
# Epoch 18/20
#  - 30s - loss: 3.3409 - accuracy: 0.2466 - val_loss: 3.3853 - val_accuracy: 0.2485
# Epoch 19/20
#  - 30s - loss: 3.3361 - accuracy: 0.2461 - val_loss: 3.3842 - val_accuracy: 0.2503
# Epoch 20/20
#  - 30s - loss: 3.3180 - accuracy: 0.2498 - val_loss: 3.3925 - val_accuracy: 0.2474

# %%
# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Val'], loc='upper left')
plt.show()
